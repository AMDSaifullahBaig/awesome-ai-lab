# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
data=load_iris()
x=data["data"]
y=data["target"]
scaler=StandardScaler()
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=50)
train_x_scaled=scaler.fit_transform(train_x)
test_x_scaled=scaler.transform(test_x)
accuracy=[]
for i in [0.1,0.5,0.6,0.9,1,5,10,11]:
    model=SVC(C=i)
    model.fit(train_x_scaled,train_y)
    result=model.predict(test_x_scaled)
    score=accuracy_score(result,test_y)
    accuracy.append(score)
plt.plot([0.1,0.5,0.6,0.9,1,5,10,11],accuracy)
plt.show()

# %% [markdown]
# ## C Experiment
#
# Tested different values of C:
#
# | C | Accuracy |
# |---:|---:|
# | 0.1 | 90.00% |
# | 0.5 | 93.33% |
# | 0.6 | 93.33% |
# | 0.9 | 93.33% |
# | 1 | 93.33% |
# | 5 | 93.33% |
# | 10 | 90.00% |
# | 11 | 90.00% |
#
# ### Observation
#
# The accuracy increased from 90.00% at C=0.1 to 93.33% at C=0.5
# and remained at 93.33% for values between 0.5 and 5.
#
# Increasing C further to 10 and 11 resulted in an accuracy of 90.00%.
#
# The results show that increasing C does not necessarily lead to higher
# accuracy. The effect of C depends on the dataset and the particular
# train/test split used.
