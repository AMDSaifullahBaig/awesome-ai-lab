# %%
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import dendrogram,linkage
import matplotlib.pyplot as plt

# %%
data=load_iris()
x=data.data
y=data.target
linked=linkage(x,method="ward")
plt.figure(figsize=(12, 6))
dendrogram(linked)
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")

plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
for i in ["ward","single","average","complete"]:
    model=AgglomerativeClustering(n_clusters=3,linkage=i)
    model.fit(x)
    print(i,":",silhouette_score(x,model.labels_))
# Out:
# ward : 0.5543236611296419
# single : 0.5121107753649307
# average : 0.5541608580282851
# complete : 0.5135953221192214
